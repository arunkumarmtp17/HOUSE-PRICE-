# %% [markdown]
# <a href="https://colab.research.google.com/github/arunkumarmtp17/HOUSE-PRICE-/blob/main/house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
null_counts = df.isnull().sum()
selected_columns = null_counts.loc[null_counts > 600]
selected_index = selected_columns.index
print(selected_columns)
print(selected_index)
# Out:
# Alley          1369
# FireplaceQu     690
# PoolQC         1453
# Fence          1179
# MiscFeature    1406
# dtype: int64
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df=df.drop(["Alley","MiscFeature","FireplaceQu","Fence","PoolQC"],axis=1)

# %%
null_counts = df.isnull().sum()
selected_columns = null_counts.loc[null_counts > 1]
selected_index = selected_columns.index
print(selected_columns)
print(selected_index)
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64
# Index(['LotFrontage', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1094, 76)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1094 non-null   int64
#  1   MSSubClass     1094 non-null   int64
#  2   MSZoning       1094 non-null   object
#  3   LotFrontage    1094 non-null   float64
#  4   LotArea        1094 non-null   int64
#  5   Street         1094 non-null   object
#  6   LotShape       1094 non-null   object
#  7   LandContour    1094 non-null   object
#  8   Utilities      1094 non-null   object
#  9   LotConfig      1094 non-null   object
#  10  LandSlope      1094 non-null   object
#  11  Neighborhood   1094 non-null   object
#  12  Condition1     1094 non-null   object
#  13  Condition2     1094 non-null   object
#  14  BldgType       1094 non-null   object
#  15  HouseStyle     1094 non-null   object
#  16  OverallQual    1094 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 76, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column])

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60         3         65.0     8450       1         3
# 1        2          20         3         80.0     9600       1         3
# 2        3          60         3         68.0    11250       1         0
# 3        4          70         3         60.0     9550       1         0
# 4        5          60         3         84.0    14260       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60         3         62.0     7917       1         3
# 1456  1457          20         3         85.0    13175       1         3
# 1457  1458          70         3         66.0     9042       1         3
# 1458  1459          20         3         68.0     9717       1         3
# 1459  1460          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x=df.drop(['Id','SalePrice'],axis=1)

# %%
y=df['SalePrice']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
a=LinearRegression()
a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=a.predict(x_test)

# %%
y_pred
# Out:
# array([167488.31923793, 256254.28195926, 769895.20245456, 200618.10681368,
#        292174.84185058, 105232.75455748, 203202.07444714, 166501.36803844,
#        246508.70799532, 278526.65048898, 267541.29965226, 261603.40002414,
#        242347.00701088, 151033.92188851, 265019.59935731, 195831.97279581,
#        199043.75274764, 123418.70925447, 184612.37595756, 120751.19735064,
#        150043.07738086, 127277.57251216, 185270.07243836, 110887.81971874,
#        136333.1299352 , 119653.58531442, 345421.48899161, 142128.49975147,
#        239044.36052161, 198240.36238497, 127066.83430452, 298868.20479564,
#        223578.08722779, 111878.88024193, 182875.75343293,  82905.15975631,
#        155455.55568389, 139770.90068   , 173516.83140314, 210382.01549227,
#        208474.52002324, 152210.63635577, 260969.34227367,  64934.51258643,
#        142712.1685322 , 169394.73594943, 380543.71274464, 112018.60615825,
# ...

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.8430020344511473
